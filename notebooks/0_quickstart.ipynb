# %% [markdown]
# # FPLstat quickstart
# This quickstart guide will help you get started with the `FPLstat` package for loading and transforming Fantasy Premier League (FPL) data.
#
# ## 1. The `FPLstat` client
# The main entry point for using the `FPLstat` package is the `FPLstat` class.

# %%
from fplstat import FPLStat

# %%
fpl = FPLStat()

# %%
players = fpl.get_players()

# %%
players[:3]
# Out:
# [Player(id=1, web_name='Raya', first_name='David', second_name='Raya Martín', photo='154561.jpg', element_type=1, team=1, team_code=3, now_cost=5.9, selected_by_percent=32.2, cost_change_start=4, cost_change_event=0, cost_change_start_fall=-4, cost_change_event_fall=0, total_points=53, event_points=1, form=4.3, points_per_game=4.8, value_form=0.7, value_season=9.0, status='a', chance_of_playing_this_round=None, chance_of_playing_next_round=None, news='', news_added=None, minutes=990, goals_scored=0, assists=0, clean_sheets=7, goals_conceded=5, own_goals=0, penalties_saved=0, penalties_missed=0, yellow_cards=1, red_cards=0, saves=16, bonus=3, bps=210, starts=11, influence=159.8, creativity=10.2, threat=0.0, ict_index=17.0, expected_goals=0.0, expected_assists=0.04, expected_goal_involvements=0.04, expected_goals_conceded=6.17, expected_goals_per_90=0.0, expected_assists_per_90=0.0, expected_goal_involvements_per_90=0.0, expected_goals_conceded_per_90=0.56, goals_conceded_per_90=0.45, saves_per_90=1.45, starts_per_90=1.0, clean_sheets_per_90=0.64, defensive_contribution_per_90=0.0, influence_rank=116, influence_rank_type=15, creativity_rank=346, creativity_rank_type=3, threat_rank=739, threat_rank_type=86, ict_index_rank=250, ict_index_rank_type=16, form_rank=73, form_rank_type=6, points_per_game_rank=39, points_per_game_rank_type=2, selected_rank=9, selected_rank_type=2, now_cost_rank=94, now_cost_rank_type=1, transfers_in=2341403, transfers_in_event=67622, transfers_out=923898, transfers_out_event=67999, corners_and_indirect_freekicks_order=None, corners_and_indirect_freekicks_text='', direct_freekicks_order=None, direct_freekicks_text='', penalties_order=None, penalties_text='', clearances_blocks_interceptions=9, recoveries=87, tackles=0, defensive_contribution=0, dreamteam_count=1, can_select=True, can_transact=True, in_dreamteam=False, removed=False, special=False, has_temporary_code=False, region=200, birth_date=datetime.date(1995, 9, 15), team_join_date=datetime.date(2024, 7, 4), code=154561, opta_code='p154561', squad_number=None, ep_this=5.3, ep_next=5.3),
#  Player(id=2, web_name='Arrizabalaga', first_name='Kepa', second_name='Arrizabalaga Revuelta', photo='109745.jpg', element_type=1, team=1, team_code=3, now_cost=4.2, selected_by_percent=0.4, cost_change_start=-3, cost_change_event=0, cost_change_start_fall=3, cost_change_event_fall=0, total_points=0, event_points=0, form=0.0, points_per_game=0.0, value_form=0.0, value_season=0.0, status='a', chance_of_playing_this_round=None, chance_of_playing_next_round=None, news='', news_added=None, minutes=0, goals_scored=0, assists=0, clean_sheets=0, goals_conceded=0, own_goals=0, penalties_saved=0, penalties_missed=0, yellow_cards=0, red_cards=0, saves=0, bonus=0, bps=0, starts=0, influence=0.0, creativity=0.0, threat=0.0, ict_index=0.0, expected_goals=0.0, expected_assists=0.0, expected_goal_involvements=0.0, expected_goals_conceded=0.0, expected_goals_per_90=0.0, expected_assists_per_90=0.0, expected_goal_involvements_per_90=0.0, expected_goals_conceded_per_90=0.0, goals_conceded_per_90=0.0, saves_per_90=0.0, starts_per_90=0.0, clean_sheets_per_90=0.0, defensive_contribution_per_90=0.0, influence_rank=553, influence_rank_type=76, creativity_rank=538, creativity_rank_type=62, threat_rank=506, threat_rank_type=49, ict_index_rank=554, ict_index_rank_type=76, form_rank=487, form_rank_type=68, points_per_game_rank=559, points_per_game_rank_type=75, selected_rank=249, selected_rank_type=34, now_cost_rank=608, now_cost_rank_type=38, transfers_in=8218, transfers_in_event=351, transfers_out=61194, transfers_out_event=1433, corners_and_indirect_freekicks_order=None, corners_and_indirect_freekicks_text='', direct_freekicks_order=None, direct_freekicks_text='', penalties_order=None, penalties_text='', clearances_blocks_interceptions=0, recoveries=0, tackles=0, defensive_contribution=0, dreamteam_count=0, can_select=True, can_transact=True, in_dreamteam=False, removed=False, special=False, has_temporary_code=False, region=200, birth_date=datetime.date(1994, 10, 3), team_join_date=datetime.date(2025, 7, 1), code=109745, opta_code='p109745', squad_number=None, ep_this=1.0, ep_next=1.0),
#  Player(id=3, web_name='Hein', first_name='Karl', second_name='Hein', photo='463748.jpg', element_type=1, team=1, team_code=3, now_cost=4.0, selected_by_percent=0.3, cost_change_start=0, cost_change_event=0, cost_change_start_fall=0, cost_change_event_fall=0, total_points=0, event_points=0, form=0.0, points_per_game=0.0, value_form=0.0, value_season=0.0, status='u', chance_of_playing_this_round=0, chance_of_playing_next_round=0, news='Has joined Werder Bremen on loan for the rest of the season.', news_added=datetime.datetime(2025, 8, 26, 13, 44, 2, 357864, tzinfo=TzInfo(UTC)), minutes=0, goals_scored=0, assists=0, clean_sheets=0, goals_conceded=0, own_goals=0, penalties_saved=0, penalties_missed=0, yellow_cards=0, red_cards=0, saves=0, bonus=0, bps=0, starts=0, influence=0.0, creativity=0.0, threat=0.0, ict_index=0.0, expected_goals=0.0, expected_assists=0.0, expected_goal_involvements=0.0, expected_goals_conceded=0.0, expected_goals_per_90=0.0, expected_assists_per_90=0.0, expected_goal_involvements_per_90=0.0, expected_goals_conceded_per_90=0.0, goals_conceded_per_90=0.0, saves_per_90=0.0, starts_per_90=0.0, clean_sheets_per_90=0.0, defensive_contribution_per_90=0.0, influence_rank=518, influence_rank_type=64, creativity_rank=503, creativity_rank_type=50, threat_rank=470, threat_rank_type=37, ict_index_rank=519, ict_index_rank_type=64, form_rank=449, form_rank_type=56, points_per_game_rank=525, points_per_game_rank_type=63, selected_rank=326, selected_rank_type=47, now_cost_rank=649, now_cost_rank_type=58, transfers_in=5545, transfers_in_event=0, transfers_out=41041, transfers_out_event=818, corners_and_indirect_freekicks_order=None, corners_and_indirect_freekicks_text='', direct_freekicks_order=None, direct_freekicks_text='', penalties_order=None, penalties_text='', clearances_blocks_interceptions=0, recoveries=0, tackles=0, defensive_contribution=0, dreamteam_count=0, can_select=False, can_transact=True, in_dreamteam=False, removed=False, special=False, has_temporary_code=False, region=67, birth_date=datetime.date(2002, 4, 13), team_join_date=datetime.date(2020, 10, 28), code=463748, opta_code='p463748', squad_number=None, ep_this=0.0, ep_next=0.0)]

# %%
fixtures = fpl.get_fixtures()

# %%
fixtures[:3]
# Out:
# [Fixture(code=2561895, event=1, finished=True, finished_provisional=True, id=1, kickoff_time=datetime.datetime(2025, 8, 15, 19, 0, tzinfo=TzInfo(UTC)), minutes=90, provisional_start_time=False, pulse_id=124791, started=True, stats=[{'identifier': 'goals_scored', 'a': [{'value': 2, 'element': 82}], 'h': [{'value': 1, 'element': 381}, {'value': 1, 'element': 384}, {'value': 1, 'element': 385}, {'value': 1, 'element': 661}]}, {'identifier': 'assists', 'a': [{'value': 1, 'element': 86}, {'value': 1, 'element': 93}], 'h': [{'value': 1, 'element': 386}, {'value': 1, 'element': 392}, {'value': 1, 'element': 661}]}, {'identifier': 'own_goals', 'a': [], 'h': []}, {'identifier': 'penalties_saved', 'a': [], 'h': []}, {'identifier': 'penalties_missed', 'a': [], 'h': []}, {'identifier': 'yellow_cards', 'a': [{'value': 1, 'element': 86}, {'value': 1, 'element': 97}], 'h': [{'value': 1, 'element': 371}]}, {'identifier': 'red_cards', 'a': [], 'h': []}, {'identifier': 'saves', 'a': [{'value': 6, 'element': 67}], 'h': [{'value': 1, 'element': 366}]}, {'identifier': 'bonus', 'a': [{'value': 3, 'element': 82}], 'h': [{'value': 2, 'element': 661}, {'value': 1, 'element': 381}]}, {'identifier': 'bps', 'a': [{'value': 42, 'element': 82}, {'value': 23, 'element': 86}, {'value': 20, 'element': 84}, {'value': 12, 'element': 93}, {'value': 11, 'element': 85}, {'value': 10, 'element': 67}, {'value': 7, 'element': 90}, {'value': 3, 'element': 96}, {'value': 2, 'element': 73}, {'value': 2, 'element': 100}, {'value': 2, 'element': 685}, {'value': 1, 'element': 72}, {'value': -1, 'element': 74}, {'value': -1, 'element': 97}], 'h': [{'value': 37, 'element': 661}, {'value': 36, 'element': 381}, {'value': 34, 'element': 384}, {'value': 29, 'element': 385}, {'value': 27, 'element': 386}, {'value': 17, 'element': 387}, {'value': 15, 'element': 392}, {'value': 14, 'element': 382}, {'value': 11, 'element': 373}, {'value': 8, 'element': 366}, {'value': 8, 'element': 370}, {'value': 6, 'element': 374}, {'value': 5, 'element': 371}, {'value': 4, 'element': 388}, {'value': -1, 'element': 376}, {'value': -3, 'element': 372}]}, {'identifier': 'defensive_contribution', 'a': [{'value': 20, 'element': 84}, {'value': 19, 'element': 85}, {'value': 15, 'element': 72}, {'value': 9, 'element': 73}, {'value': 9, 'element': 685}, {'value': 7, 'element': 86}, {'value': 6, 'element': 74}, {'value': 5, 'element': 82}, {'value': 5, 'element': 97}, {'value': 4, 'element': 93}, {'value': 3, 'element': 90}, {'value': 2, 'element': 77}], 'h': [{'value': 21, 'element': 373}, {'value': 11, 'element': 387}, {'value': 10, 'element': 381}, {'value': 9, 'element': 382}, {'value': 8, 'element': 384}, {'value': 7, 'element': 374}, {'value': 6, 'element': 371}, {'value': 6, 'element': 386}, {'value': 4, 'element': 370}, {'value': 3, 'element': 392}, {'value': 2, 'element': 372}, {'value': 1, 'element': 376}, {'value': 1, 'element': 385}, {'value': 1, 'element': 388}, {'value': 1, 'element': 661}]}], team_a=4, team_a_difficulty=4, team_a_score=2, team_h=12, team_h_difficulty=3, team_h_score=4),
#  Fixture(code=2561896, event=1, finished=True, finished_provisional=True, id=2, kickoff_time=datetime.datetime(2025, 8, 16, 11, 30, tzinfo=TzInfo(UTC)), minutes=90, provisional_start_time=False, pulse_id=124792, started=True, stats=[{'identifier': 'goals_scored', 'a': [], 'h': []}, {'identifier': 'assists', 'a': [], 'h': []}, {'identifier': 'own_goals', 'a': [], 'h': []}, {'identifier': 'penalties_saved', 'a': [], 'h': []}, {'identifier': 'penalties_missed', 'a': [], 'h': []}, {'identifier': 'yellow_cards', 'a': [{'value': 1, 'element': 490}], 'h': [{'value': 1, 'element': 58}]}, {'identifier': 'red_cards', 'a': [], 'h': [{'value': 1, 'element': 38}]}, {'identifier': 'saves', 'a': [{'value': 3, 'element': 469}], 'h': [{'value': 3, 'element': 33}]}, {'identifier': 'bonus', 'a': [{'value': 3, 'element': 477}, {'value': 2, 'element': 469}, {'value': 1, 'element': 476}], 'h': []}, {'identifier': 'bps', 'a': [{'value': 33, 'element': 477}, {'value': 32, 'element': 469}, {'value': 30, 'element': 476}, {'value': 26, 'element': 474}, {'value': 26, 'element': 478}, {'value': 20, 'element': 491}, {'value': 15, 'element': 487}, {'value': 11, 'element': 488}, {'value': 10, 'element': 486}, {'value': 7, 'element': 490}, {'value': 4, 'element': 485}, {'value': 4, 'element': 497}, {'value': 3, 'element': 489}, {'value': 3, 'element': 500}], 'h': [{'value': 29, 'element': 33}, {'value': 25, 'element': 36}, {'value': 25, 'element': 40}, {'value': 22, 'element': 37}, {'value': 19, 'element': 59}, {'value': 15, 'element': 38}, {'value': 13, 'element': 58}, {'value': 12, 'element': 64}, {'value': 10, 'element': 54}, {'value': 7, 'element': 47}, {'value': 5, 'element': 48}, {'value': 4, 'element': 53}]}, {'identifier': 'defensive_contribution', 'a': [{'value': 11, 'element': 474}, {'value': 11, 'element': 476}, {'value': 9, 'element': 490}, {'value': 9, 'element': 491}, {'value': 8, 'element': 488}, {'value': 5, 'element': 477}, {'value': 4, 'element': 478}, {'value': 4, 'element': 485}, {'value': 4, 'element': 487}, {'value': 3, 'element': 486}, {'value': 2, 'element': 489}, {'value': 1, 'element': 497}], 'h': [{'value': 14, 'element': 59}, {'value': 11, 'element': 36}, {'value': 11, 'element': 58}, {'value': 7, 'element': 37}, {'value': 7, 'element': 47}, {'value': 7, 'element': 48}, {'value': 7, 'element': 54}, {'value': 5, 'element': 40}, {'value': 5, 'element': 64}, {'value': 3, 'element': 38}]}], team_a=15, team_a_difficulty=3, team_a_score=0, team_h=2, team_h_difficulty=3, team_h_score=0),
#  Fixture(code=2561897, event=1, finished=True, finished_provisional=True, id=3, kickoff_time=datetime.datetime(2025, 8, 16, 14, 0, tzinfo=TzInfo(UTC)), minutes=90, provisional_start_time=False, pulse_id=124793, started=True, stats=[{'identifier': 'goals_scored', 'a': [{'value': 1, 'element': 338}], 'h': [{'value': 1, 'element': 164}]}, {'identifier': 'assists', 'a': [{'value': 1, 'element': 329}], 'h': [{'value': 1, 'element': 158}]}, {'identifier': 'own_goals', 'a': [], 'h': []}, {'identifier': 'penalties_saved', 'a': [], 'h': []}, {'identifier': 'penalties_missed', 'a': [], 'h': []}, {'identifier': 'yellow_cards', 'a': [{'value': 1, 'element': 318}, {'value': 1, 'element': 331}, {'value': 1, 'element': 338}], 'h': [{'value': 1, 'element': 148}, {'value': 1, 'element': 157}, {'value': 1, 'element': 169}]}, {'identifier': 'red_cards', 'a': [], 'h': []}, {'identifier': 'saves', 'a': [{'value': 3, 'element': 314}], 'h': [{'value': 1, 'element': 139}]}, {'identifier': 'bonus', 'a': [{'value': 3, 'element': 338}], 'h': [{'value': 2, 'element': 164}, {'value': 1, 'element': 166}]}, {'identifier': 'bps', 'a': [{'value': 25, 'element': 338}, {'value': 17, 'element': 322}, {'value': 16, 'element': 329}, {'value': 15, 'element': 314}, {'value': 14, 'element': 317}, {'value': 11, 'element': 335}, {'value': 10, 'element': 321}, {'value': 10, 'element': 324}, {'value': 9, 'element': 332}, {'value': 3, 'element': 318}, {'value': 3, 'element': 319}, {'value': 3, 'element': 330}, {'value': 2, 'element': 325}, {'value': 1, 'element': 326}, {'value': -3, 'element': 331}], 'h': [{'value': 24, 'element': 164}, {'value': 20, 'element': 166}, {'value': 17, 'element': 173}, {'value': 16, 'element': 146}, {'value': 15, 'element': 151}, {'value': 15, 'element': 158}, {'value': 10, 'element': 167}, {'value': 9, 'element': 139}, {'value': 8, 'element': 145}, {'value': 7, 'element': 160}, {'value': 7, 'element': 169}, {'value': 3, 'element': 170}, {'value': 3, 'element': 178}, {'value': -2, 'element': 157}, {'value': -2, 'element': 162}, {'value': -5, 'element': 148}]}, {'identifier': 'defensive_contribution', 'a': [{'value': 9, 'element': 335}, {'value': 8, 'element': 317}, {'value': 7, 'element': 322}, {'value': 6, 'element': 329}, {'value': 4, 'element': 318}, {'value': 3, 'element': 321}, {'value': 3, 'element': 332}, {'value': 2, 'element': 324}, {'value': 2, 'element': 330}, {'value': 2, 'element': 331}], 'h': [{'value': 18, 'element': 173}, {'value': 11, 'element': 167}, {'value': 10, 'element': 166}, {'value': 8, 'element': 146}, {'value': 8, 'element': 151}, {'value': 6, 'element': 145}, {'value': 5, 'element': 169}, {'value': 4, 'element': 160}, {'value': 3, 'element': 164}, {'value': 2, 'element': 158}, {'value': 2, 'element': 162}, {'value': 1, 'element': 148}, {'value': 1, 'element': 178}]}], team_a=10, team_a_difficulty=3, team_a_score=1, team_h=6, team_h_difficulty=2, team_h_score=1)]
