# %% [markdown]
# # FPLstat quickstart
# This quickstart guide will help you get started with the `FPLstat` package for loading and transforming Fantasy Premier League (FPL) data.
#
# ## 1. The `FPLstat` client
# The main entry point for using the `FPLstat` package is the `FPLstat` class.

# %%
import pandas as pd
from fplstat import FPLStat

# %%
# turn off pandas' max columns display limit
pd.set_option("display.max_columns", None)

# %%
fpl = FPLStat()

# %%
players = fpl.get_players()
players.head()
# Out:
#    player_id  position_id  team_id short_name                     full_name  \
# 0          1            1        1       Raya             David Raya Martín
# 4          5            2        1    Gabriel  Gabriel dos Santos Magalhães
# 5          6            2        1     Saliba                William Saliba
# 6          7            2        1  Calafiori            Riccardo Calafiori
# 7          8            2        1   J.Timber                Jurriën Timber
#
#    price  ownership_pct  games_played  starts  minutes  points  goals_scored  \
# 0    6.0           34.1            15      15     1350      66             0
# 4    6.3           16.3            11      11      990      81             1
# 5    6.0           11.2            11      10      814      41             0
# 6    5.8           14.9            15      15     1166      71             1
# 7    6.5           35.2            15      13     1197      78             2
#
#    assists  goal_involvements  clean_sheets  goals_conceded  own_goals  \
# 0        0                  0             8               9          0
# 4        2                  3             7               5          0
# 5        0                  0             5               4          0
# 6        2                  3             8               7          0
# 7        3                  5             6               9          0
#
#    penalties_saved  penalties_missed  yellow_cards  red_cards  saves  \
# 0                0                 0             1          0     25
# 4                0                 0             1          0      0
# 5                0                 0             0          0      0
# 6                0                 0             5          0      0
# 7                0                 0             2          0      0
#
#    clearances_blocks_interceptions  recoveries  tackles  \
# 0                               11         118        0
# 4                               88          15       12
# 5                               51          35       11
# 6                               50          54       27
# 7                               41          49       40
#
#    defensive_contribution  bonus  bps  expected_goals  expected_assists  \
# 0                       0      3  267            0.00              0.04
# 4                     100     13  279            0.82              0.69
# 5                      62      1  190            0.29              0.24
# 6                      77      4  262            2.49              0.33
# 7                      81      7  282            3.11              0.72
#
#    expected_goal_involvements  expected_goals_conceded  expected_points  \
# 0                        0.04                     9.65        35.628591
# 4                        1.51                     6.17        57.913365
# 5                        0.53                     4.72        34.535661
# 6                        2.82                     6.97        56.848759
# 7                        3.83                     8.29        65.876004
#
#    starts_per_90  points_per_90  goals_per_90  assists_per_90  \
# 0           1.00       4.400000      0.000000        0.000000
# 4           1.00       7.363636      0.090909        0.181818
# 5           1.11       4.533170      0.000000        0.000000
# 6           1.16       5.480274      0.077187        0.154374
# 7           0.98       5.864662      0.150376        0.225564
#
#    goal_involvements_per_90  bonus_per_90  defensive_contribution_per_90  \
# 0                  0.000000      0.200000                           0.00
# 4                  0.272727      1.181818                           9.09
# 5                  0.000000      0.110565                           6.86
# 6                  0.231561      0.308748                           5.94
# 7                  0.375940      0.526316                           6.09
#
#    goals_conceded_per_90  saves_per_90  clean_sheets_per_90  \
# 0                   0.60          1.67                 0.53
# 4                   0.45          0.00                 0.64
# 5                   0.44          0.00                 0.55
# 6                   0.54          0.00                 0.62
# 7                   0.68          0.00                 0.45
#
#    expected_points_per_90  expected_goals_per_90  expected_assists_per_90  \
# 0                2.375239                   0.00                     0.00
# 4                5.264851                   0.07                     0.06
# 5                3.818439                   0.03                     0.03
# 6                4.387983                   0.19                     0.03
# 7                4.953083                   0.23                     0.05
#
#    expected_goal_involvements_per_90  expected_goals_conceded_per_90  \
# 0                               0.00                            0.64
# 4                               0.13                            0.56
# 5                               0.06                            0.52
# 6                               0.22                            0.54
# 7                               0.28                            0.62
#
#    influence  creativity  threat  ict_index  points_per_game  form status  \
# 0      236.6        10.2     0.0       24.7              4.4   2.8      a
# 4      318.6        62.6    88.0       46.9              7.4   0.2      i
# 5      185.2        35.6    16.0       23.7              3.7   0.6      d
# 6      203.8       100.3   219.0       52.2              4.7   2.2      s
# 7      294.0       199.1   246.0       74.1              5.2   2.4      a
#
#   scout_risks                                news  \
# 0          []
# 4          []  Thigh injury - Unknown return date
# 5          []       Knock - 75% chance of playing
# 6          []              Suspended until 20 Dec
# 7          []
#
#                         news_added  ep_this  ep_next
# 0                              NaT      3.8      3.8
# 4 2025-11-17 12:00:07.436586+00:00      0.0      0.0
# 5 2025-11-30 22:30:08.957329+00:00      1.2      1.2
# 6 2025-12-06 20:00:08.845719+00:00      3.2      0.0
# 7                              NaT      3.4      3.4

# %%
players[["short_name", "points", "expected_points"]].head(20)
# Out:
#       short_name  points  expected_points
# 0           Raya      66        35.628591
# 4        Gabriel      81        57.913365
# 5         Saliba      41        34.535661
# 6      Calafiori      71        56.848759
# 7       J.Timber      78        65.876004
# 9   Lewis-Skelly       8         8.911035
# 10         White      21        15.367003
# 14          Saka      64        71.317814
# 15      Ødegaard      19        26.128581
# 16       Madueke      16        22.724763
# 17    Martinelli      21        24.274265
# 18      Trossard      58        48.351965
# 19          Rice      84        81.953477
# 20        Merino      51        51.068396
# 22      Nørgaard       2         3.867896
# 23       Nwaneri       8        10.038576
# 24     Zubimendi      55        55.963468
# 27       Havertz       1         1.530000
# 29           Eze      65        58.009755
# 30      Mosquera      17        21.224253

# %%
fixtures = fpl.get_fixtures()

# %%
fixtures
